# %% [markdown]
# <a href="https://colab.research.google.com/github/lukasakar19-byte/Jaringan-Saraf-Tiruan/blob/main/Projek_Predik_Risiko_kredit_Lukas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Tugas Mg 2

# %% [markdown]
# ## Generate Data

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from google.colab import drive
drive.mount('/content/gdrive')
data = pd.read_csv("/content/gdrive/My Drive/Data/credit_data_clean.csv")
data.info()

X = data.drop("Bad_Risk", axis=1)
y = data["Bad_Risk"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          522 non-null    float64
#  1   Credit amount                522 non-null    float64
#  2   Duration                     522 non-null    float64
#  3   Sex_female                   522 non-null    bool
#  4   Sex_male                     522 non-null    bool
#  5   Housing_free                 522 non-null    bool
#  6   Housing_own                  522 non-null    bool
#  7   Housing_rent                 522 non-null    bool
#  8   Purpose_business             522 non-null    bool
#  9   Purpose_car                  522 non-null    bool
#  10  Purpose_domestic appliances  522 non-null    bool
#  11  Purpose_education            522 non-null    bool
#  12  Purpose_furniture/equipment  522 non-null    bool
#  13  Purpose_radio/TV             522 non-null    bool
#  14  Purpose_repairs              522 non-null    bool
#  15  Purpose_vacation/others      522 non-null    bool
#  16  Savings_Acc                  522 non-null    int64
#  17  Checking_Acc                 522 non-null    int64
#  18  Job_Skill                    522 non-null    int64
#  19  Bad_Risk                     522 non-null    int64
# dtypes: bool(13), float64(3), int64(4)
# memory usage: 35.3 KB
# Shape of X_train: (365, 19)
# Shape of X_test: (157, 19)
# Shape of y_train: (365,)
# Shape of y_test: (157,)

# %% [markdown]
# Variabel terikat dalam kode tersebut adalah Bad_Risk, yang disimpan dalam variabel y. Variabel ini merupakan target yang ingin diprediksi oleh model Artificial Neural Network (ANN), yaitu status risiko kredit nasabah.

# %%
print(data.head())
print(data.tail())
# Out:
#         Age  Credit amount  Duration  Sex_female  Sex_male  Housing_free  \
# 0 -1.094447       0.913171  2.139356        True     False         False
# 1  0.858575       1.573037  1.657897       False      True          True
# 2  1.537887       0.543768  0.213521       False      True          True
# 3  0.009435       1.253868  1.176438       False      True         False
# 4 -0.584963       0.668155  0.694979       False      True         False
#
#    Housing_own  Housing_rent  Purpose_business  Purpose_car  \
# 0         True         False             False        False
# 1        False         False             False        False
# 2        False         False             False         True
# 3        False          True             False         True
# 4         True         False             False         True
#
#    Purpose_domestic appliances  Purpose_education  \
# 0                        False              False
# 1                        False              False
# 2                        False              False
# 3                        False              False
# 4                        False              False
#
#    Purpose_furniture/equipment  Purpose_radio/TV  Purpose_repairs  \
# 0                        False              True            False
# 1                         True             False            False
# 2                        False             False            False
# 3                        False             False            False
# 4                        False             False            False
#
#    Purpose_vacation/others  Savings_Acc  Checking_Acc  Job_Skill  Bad_Risk
# 0                    False            0             1          2         1
# 1                    False            0             0          2         0
# 2                    False            0             0          2         1
# 3                    False            0             1          3         0
# 4                    False            0             1          3         1
#           Age  Credit amount  Duration  Sex_female  Sex_male  Housing_free  \
# 517  1.113317      -0.524799  0.213521       False      True         False
# 518 -0.415135       0.232459  1.176438       False      True         False
# 519  0.434005       0.197603  0.694979       False      True         False
# 520 -1.009533      -0.489943  1.898626       False      True          True
# 521 -0.669877       0.443302  1.898626       False      True         False
#
#      Housing_own  Housing_rent  Purpose_business  Purpose_car  \
# 517         True         False             False        False
# 518         True         False             False        False
# 519         True         False             False         True
# 520        False         False             False        False
# 521         True         False             False         True
#
#      Purpose_domestic appliances  Purpose_education  \
# 517                        False              False
# 518                        False              False
# 519                        False              False
# 520                        False              False
# 521                        False              False
#
#      Purpose_furniture/equipment  Purpose_radio/TV  Purpose_repairs  \
# 517                        False              True            False
# 518                         True             False            False
# 519                        False             False            False
# 520                        False              True            False
# 521                        False             False            False
#
#      Purpose_vacation/others  Savings_Acc  Checking_Acc  Job_Skill  Bad_Risk
# 517                    False            0             1          1         0
# 518                    False            0             0          3         0
# 519                    False            0             0          3         0
# 520                    False            0             0          2         1
# 521                    False            1             1          2         0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_30 (Dense)                │ (None, 64)             │         1,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,393 (13.25 KB)
#  Trainable params: 3,393 (13.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# bangun model ANN dengan dua hidden layer (ReLU) dan satu output layer (sigmoid) untuk klasifikasi biner Bad_Risk. Model dikompilasi dengan optimizer Adam dan loss binary cross-entropy, lalu model.summary() menampilkan struktur jaringan yang dibuat.

# %% [markdown]
# ## Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Fungsi untuk membuat model baru (reset setiap run)
def create_model():
    model = Sequential([
        Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
        Dense(32, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model
# Kombinasi parameter
configs = [
    (5, 16),
    (10, 16),
    (5, 32),
    (10, 32)
]
histories = {}
trained_models = {} # Initialize a dictionary to store trained models
for epochs, batch_size in configs:
    print(f"\nTraining dengan epochs={epochs}, batch_size={batch_size}")

    model = create_model()  # reset model
    key = f"epochs_{epochs}_batch_{batch_size}"
    trained_models[key] = model # Store the trained model in the dictionary

    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=0.2,
        verbose=1
    )
    histories[key] = history
print("\nSemua kombinasi training selesai. History tersimpan di 'histories'.")
print("Semua model terlatih tersimpan di 'trained_models'.")
# Out:
# Training dengan epochs=5, batch_size=16
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5415 - loss: 0.6799 - val_accuracy: 0.6027 - val_loss: 0.6896
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6369 - loss: 0.6224 - val_accuracy: 0.6301 - val_loss: 0.6723
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7026 - loss: 0.5938 - val_accuracy: 0.6301 - val_loss: 0.6596
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7162 - loss: 0.5757 - val_accuracy: 0.6301 - val_loss: 0.6548
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7130 - loss: 0.5315 - val_accuracy: 0.6301 - val_loss: 0.6465
#
# Training dengan epochs=10, batch_size=16
# Epoch 1/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5399 - loss: 0.6996 - val_accuracy: 0.6164 - val_loss: 0.6762
# Epoch 2/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6843 - loss: 0.6246 - val_accuracy: 0.6301 - val_loss: 0.6567
# Epoch 3/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6595 - loss: 0.6206 - val_accuracy: 0.6301 - val_loss: 0.6449
# Epoch 4/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6797 - loss: 0.5948 - val_accuracy: 0.6301 - val_loss: 0.6335
# Epoch 5/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7043 - loss: 0.5756 - val_accuracy: 0.6438 - val_loss: 0.6353
# Epoch 6/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7136 - loss: 0.5582 - val_accuracy: 0.6712 - val_loss: 0.6398
# Epoch 7/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7402 - loss: 0.5374 - val_accuracy: 0.6986 - val_loss: 0.6366
# Epoch 8/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7656 - loss: 0.5165 - val_accuracy: 0.6849 - val_loss: 0.6421
# Epoch 9/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7382 - loss: 0.5151 - val_accuracy: 0.6849 - val_loss: 0.6419
# Epoch 10/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7759 - loss: 0.4783 - val_accuracy: 0.6575 - val_loss: 0.6422
#
# Training dengan epochs=5, batch_size=32
# Epoch 1/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.4553 - loss: 0.7659 - val_accuracy: 0.4247 - val_loss: 0.7282
# Epoch 2/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5020 - loss: 0.6759 - val_accuracy: 0.5205 - val_loss: 0.6919
# Epoch 3/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5970 - loss: 0.6572 - val_accuracy: 0.5616 - val_loss: 0.6720
# Epoch 4/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6856 - loss: 0.6221 - val_accuracy: 0.6164 - val_loss: 0.6621
# Epoch 5/5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6987 - loss: 0.5886 - val_accuracy: 0.6027 - val_loss: 0.6615
#
# Training dengan epochs=10, batch_size=32
# Epoch 1/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.4711 - loss: 0.7386 - val_accuracy: 0.5205 - val_loss: 0.7034
# Epoch 2/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5785 - loss: 0.6807 - val_accuracy: 0.5479 - val_loss: 0.6703
# Epoch 3/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6734 - loss: 0.6338 - val_accuracy: 0.6027 - val_loss: 0.6586
# Epoch 4/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6774 - loss: 0.6211 - val_accuracy: 0.6164 - val_loss: 0.6500
# Epoch 5/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6770 - loss: 0.6139 - val_accuracy: 0.6712 - val_loss: 0.6428
# Epoch 6/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6907 - loss: 0.5993 - val_accuracy: 0.6575 - val_loss: 0.6364
# Epoch 7/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6751 - loss: 0.5854 - val_accuracy: 0.6575 - val_loss: 0.6329
# Epoch 8/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7389 - loss: 0.5632 - val_accuracy: 0.6438 - val_loss: 0.6300
# Epoch 9/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7184 - loss: 0.5698 - val_accuracy: 0.6301 - val_loss: 0.6281
# Epoch 10/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7293 - loss: 0.5480 - val_accuracy: 0.6575 - val_loss: 0.6269
#
# Semua kombinasi training selesai. History tersimpan di 'histories'.
# Semua model terlatih tersimpan di 'trained_models'.

# %% [markdown]
# ## Prediksi Model

# %%
for key, model in trained_models.items():
    print(f"\nPrediksi untuk model: {key}")

    y_pred_proba = model.predict(X_test)
    y_pred_classes = (y_pred_proba > 0.5).astype(int)

    print("First 5 predicted probabilities:")
    print(y_pred_proba[:5].flatten())

    print("First 5 predicted classes:")
    print(y_pred_classes[:5].flatten())
# Out:
# Prediksi untuk model: epochs_5_batch_16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# First 5 predicted probabilities:
# [0.42238674 0.572538   0.7125021  0.23766662 0.03219562]
# First 5 predicted classes:
# [0 1 1 0 0]
#
# Prediksi untuk model: epochs_10_batch_16
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# First 5 predicted probabilities:
# [0.44319585 0.50968766 0.8209047  0.1716423  0.06086404]
# First 5 predicted classes:
# [0 1 1 0 0]
#
# Prediksi untuk model: epochs_5_batch_32
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# First 5 predicted probabilities:
# [0.45675513 0.57620555 0.7116168  0.36599964 0.12463883]
# First 5 predicted classes:
# [0 1 1 0 0]
#
# Prediksi untuk model: epochs_10_batch_32
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# First 5 predicted probabilities:
# [0.47627693 0.4780853  0.79991055 0.2824874  0.09950241]
# First 5 predicted classes:
# [0 0 1 0 0]

# %% [markdown]
# Output menunjukkan bahwa perbedaan epochs dan batch size sedikit memengaruhi nilai probabilitas prediksi. Sebagian besar model menghasilkan kelas yang sama, namun pada satu kombinasi terjadi perubahan kelas karena probabilitasnya melewati batas 0,5. Secara umum, hasil prediksi antar-model masih relatif konsisten.

# %% [markdown]
# ## Evaluasi Model

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

for key, model in trained_models.items():
    print(f"\n=== Evaluasi untuk {key} ===")

    # Prediksi
    y_pred_proba = model.predict(X_test)
    y_pred_classes = (y_pred_proba > 0.5).astype(int)

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred_classes)
    print("Confusion Matrix:")
    print(cm)

    # Metrics
    acc = accuracy_score(y_test, y_pred_classes)
    prec = precision_score(y_test, y_pred_classes)
    rec = recall_score(y_test, y_pred_classes)
    f1 = f1_score(y_test, y_pred_classes)

    print(f"Accuracy  : {acc:.4f}")
    print(f"Precision : {prec:.4f}")
    print(f"Recall    : {rec:.4f}")
    print(f"F1-Score  : {f1:.4f}")
# Out:
# === Evaluasi untuk epochs_5_batch_16 ===
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Confusion Matrix:
# [[61 25]
#  [44 27]]
# Accuracy  : 0.5605
# Precision : 0.5192
# Recall    : 0.3803
# F1-Score  : 0.4390
#
# === Evaluasi untuk epochs_10_batch_16 ===
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Confusion Matrix:
# [[57 29]
#  [37 34]]
# Accuracy  : 0.5796
# Precision : 0.5397
# Recall    : 0.4789
# F1-Score  : 0.5075
#
# === Evaluasi untuk epochs_5_batch_32 ===
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Confusion Matrix:
# [[62 24]
#  [40 31]]
# Accuracy  : 0.5924
# Precision : 0.5636
# Recall    : 0.4366
# F1-Score  : 0.4921
#
# === Evaluasi untuk epochs_10_batch_32 ===
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Confusion Matrix:
# [[59 27]
#  [43 28]]
# Accuracy  : 0.5541
# Precision : 0.5091
# Recall    : 0.3944
# F1-Score  : 0.4444

# %% [markdown]
# Hasil evaluasi menunjukkan bahwa kombinasi parameter memengaruhi kinerja model. Model epochs_5_batch_32 memiliki accuracy tertinggi (0.5924), sedangkan model epochs_10_batch_16 memiliki F1-score tertinggi (0.5075), yang berarti lebih seimbang antara precision dan recall. Secara umum, seluruh model masih memiliki performa sedang (accuracy sekitar 55–59%), dengan recall yang relatif rendah, menunjukkan bahwa model masih cukup sering gagal mendeteksi nasabah dengan risiko buruk. Dari hasil ini, kombinasi epochs_10_batch_16 dapat dianggap paling stabil karena memberikan keseimbangan prediksi yang lebih baik.

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# Kesimpulannya, model ANN sudah dapat memprediksi risiko kredit tetapi performanya masih sedang (accuracy sekitar 55–59%). Kombinasi epochs_10_batch_16 menjadi yang paling baik karena paling seimbang antara precision dan recall. Namun, model masih perlu peningkatan agar lebih akurat dalam mendeteksi risiko kredit buruk.
